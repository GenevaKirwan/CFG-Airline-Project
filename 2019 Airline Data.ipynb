# %% [markdown]
# Data Visualisation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
#Heatmap of fuel consumption and emission data.
df1 = pd.read_csv('Fuel-DataEmissions-Table.csv')
df1.columns
# Out:
# Index(['IATA Code', 'Airline Name', 'Year', 'Month', 'Month Number', 'Quarter',
#        'Total Fuel Consumed (thousands of gallons)',
#        'Total Cost of Fuel (dollars)', 'Cost per Gallon (dollars)',
#        'Total Fuel Consumed (thousands of kg) ',
#        'CO2 Emissions (thousands of kg)'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df1.corr(), annot =True, linewidth =0.5, cmap ='RdPu')
# Out:
# <AxesSubplot:>

# %%
#Using already cleaned and analysed airline data, I have focused on 2019
#data to create a new table and identify correlations of recent developments.

#As explained in the report, some data cannot be found, these have been 
#marked as 'NaN' in the below dataframe.

import csv

header = ['Airline Name', 'Fleet Size', 'No. of Passengers', 'Revenue (billions of $)', 'Total CO2 Emissions (thousands of kg)', 'Ticket Price p/Mile (average in $)']
data = [
    ['American', 877, 156153025, 45.768, 3.493181e+07, 1.393249341],
    ['Southwest', 718, 166799208, 22.428, 1.981933e+07, 1.163601856],
    ['Delta', 750, 162825498, 47.007, 3.450202e+07, 1.467712043],
    ['United', 782, 116742820, 43.259, 3.386846e+07, 1.245208498],
    ['Spirit', 155, 34535559, 3.831, 4.494868e+06],
    ['Alaska', 197, 36021420, 8.781, 6.967189e+06, 1.383989632],
    ['JetBlue', 267, 42836473, 8.094, 8.451378e+06, 1.118931656],
    ['SkyWest', 561, 42461185, 2.972, 9.944033e+05],
    ['Frontier', 104, 22823412, '', 2.753693e+06, 0.591675017],
    ['Hawaiin', 59, 11535119, 2.832, 2.572453e+06]
]

with open('airlinedata2019.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(data)

# %%
dfx = pd.read_csv('airlinedata2019.csv')
dfx
# Out:
#   Airline Name  Fleet Size  No. of Passengers  Revenue (billions of $)  \
# 0     American         877          156153025                   45.768
# 1    Southwest         718          166799208                   22.428
# 2        Delta         750          162825498                   47.007
# 3       United         782          116742820                   43.259
# 4       Spirit         155           34535559                    3.831
# 5       Alaska         197           36021420                    8.781
# 6      JetBlue         267           42836473                    8.094
# 7      SkyWest         561           42461185                    2.972
# 8     Frontier         104           22823412                      NaN
# 9      Hawaiin          59           11535119                    2.832
#
#    Total CO2 Emissions (thousands of kg)  Ticket Price p/Mile (average in $)
# 0                             34931810.0                            1.393249
# ...

# %%
plt.figure(figsize=(5,2))
sns.heatmap(dfx.corr(), annot =True, linewidth =0.5, cmap ='RdPu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data Visualisation Experimentation

# %%
#Correlation between total passengers carried and CO2 emissions for
#the studied airlines for 2019.

dfx[['No. of Passengers', 'Total CO2 Emissions (thousands of kg)']].plot.line()
# Out:
# <AxesSubplot:>

# %%
dfx[['Revenue (billions of $)', 'Total CO2 Emissions (thousands of kg)']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dfx[['Airline Name', 'Fleet Size', 'No. of Passengers', 'Revenue (billions of $)', 'Total CO2 Emissions (thousands of kg)',]].plot.line()
# Out:
# <AxesSubplot:>

# %%
dfx[['Airline Name', 'Fleet Size', 'No. of Passengers', 'Revenue (billions of $)', 'Total CO2 Emissions (thousands of kg)', 'Ticket Price p/Mile (average in $)']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
